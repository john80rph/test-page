# %% [markdown]
# <a href="https://colab.research.google.com/github/john80rph/test-page/blob/main/testcoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello everyone")
# Out:
# hello everyone

# %%
print("bacitracin")
# Out:
# bacitracin

# %%
4+4
# Out:
# 8

# %%
4+f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2565789362.py in <cell line: 0>()
# ----> 1 4+f
#
# NameError: name 'f' is not defined
