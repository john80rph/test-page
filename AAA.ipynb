# %% [markdown]
# <a href="https://colab.research.google.com/github/john80rph/test-page/blob/main/AAA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("AAA")
# Out:
# AAA
